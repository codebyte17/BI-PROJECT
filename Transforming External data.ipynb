# %%
import pandas as pd

# %%
data_frame = pd.read_csv("Unemployment in America Per US State.csv")

# %%
data_frame.head()
# Out:
#    FIPS Code  State/Area  Year  Month  \
# 0          1     Alabama  1976      1
# 1          2      Alaska  1976      1
# 2          4     Arizona  1976      1
# 3          5    Arkansas  1976      1
# 4          6  California  1976      1
#
#   Total Civilian Non-Institutional Population in State/Area  \
# 0                                       2,605,000
# 1                                         232,000
# 2                                       1,621,000
# 3                                       1,536,000
# 4                                      15,621,000
#
#   Total Civilian Labor Force in State/Area  \
# 0                             1,484,555
# 1                               160,183
# 2                               964,120
# 3                               889,044
# 4                             9,774,280
#
#    Percent (%) of State/Area's Population Total Employment in State/Area  \
# 0                                    57.0                   1,386,023
# ...

# %%
data_frame.columns
# Out:
# Index(['FIPS Code', 'State/Area', 'Year', 'Month',
#        'Total Civilian Non-Institutional Population in State/Area',
#        'Total Civilian Labor Force in State/Area',
#        'Percent (%) of State/Area's Population',
#        'Total Employment in State/Area',
#        'Percent (%) of Labor Force Employed in State/Area',
#        'Total Unemployment in State/Area',
#        'Percent (%) of Labor Force Unemployed in State/Area'],
#       dtype='object')

# %%
new_dataframe = data_frame[["State/Area","Year","Month","Total Unemployment in State/Area","Total Employment in State/Area",'Total Civilian Labor Force in State/Area','Total Civilian Non-Institutional Population in State/Area']]

# %%
new_dataframe.head()
# Out:
#    State/Area  Year  Month Total Unemployment in State/Area  \
# 0     Alabama  1976      1                        98,532
# 1      Alaska  1976      1                        11,363
# 2     Arizona  1976      1                        98,249
# 3    Arkansas  1976      1                        64,649
# 4  California  1976      1                       898,595
#
#   Total Employment in State/Area Total Civilian Labor Force in State/Area  \
# 0                   1,386,023                                1,484,555
# 1                     148,820                                  160,183
# 2                     865,871                                  964,120
# 3                     824,395                                  889,044
# 4                   8,875,685                                9,774,280
#
#   Total Civilian Non-Institutional Population in State/Area
# 0                                       2,605,000
# 1                                         232,000
# ...

# %%
new_dataframe = new_dataframe[new_dataframe["Year"]==2006]

# %%
new_dataframe = new_dataframe[new_dataframe["Month"].isin([3,4,5])]

# %%
new_dataframe.describe()
# Out:
#          Year       Month
# count   159.0  159.000000
# mean   2006.0    4.000000
# std       0.0    0.819076
# min    2006.0    3.000000
# 25%    2006.0    3.000000
# 50%    2006.0    4.000000
# 75%    2006.0    5.000000
# max    2006.0    5.000000

# %%
new_dataframe.to_csv("new_data.csv",index=False)

# %%
new_dataframe.dtypes
# Out:
# State/Area                                                   object
# Year                                                          int64
# Month                                                         int64
# Total Unemployment in State/Area                             object
# Total Employment in State/Area                               object
# Total Civilian Labor Force in State/Area                     object
# Total Civilian Non-Institutional Population in State/Area    object
# dtype: object
